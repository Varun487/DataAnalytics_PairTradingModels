# %%
import os
import numpy as np
import pandas as pd
import plotly.express as px
from datetime import datetime

# %% [markdown]
# # Get the stock to visualize from the user

# %%
stock_ticker = "TCSNSE"

try:
    stock_df = pd.read_csv(f"../Storage/Companies_with_bollinger_bands/{stock_ticker}.csv", index_col=[0])
except:
    stock_df = None
    print("Stock Unavailable")

# %%
stock_df.head()
# Out:
#                    High          Low         Open        Close     Volume  \
# Date
# 2017-09-14  1248.800049  1235.949951  1241.000000  1243.469971  1081510.0
# 2017-09-15  1258.500000  1242.500000  1249.500000  1253.030029  2944072.0
# 2017-09-18  1259.469971  1244.619995  1252.469971  1249.530029   726600.0
# 2017-09-19  1252.500000  1245.750000  1252.500000  1249.119995   782754.0
# 2017-09-20  1257.000000  1237.150024  1257.000000  1246.780029  1334642.0
#
#               Adj Close Company Exchange        SMA20  SMA20_Upper_std1  \
# Date
# 2017-09-14  1165.811523     TCS      NSE  1243.469971       1250.229953
# 2017-09-15  1174.774414     TCS      NSE  1248.250000       1255.009982
# 2017-09-18  1171.492920     TCS      NSE  1248.676676       1253.513498
# 2017-09-19  1171.108521     TCS      NSE  1248.787506       1252.742970
# 2017-09-20  1168.914917     TCS      NSE  1248.386011       1251.927234
#
#             SMA20_Upper_std2  SMA20_Upper_std3  SMA20_Lower_std1  \
# ...

# %%
fig = go.Figure(data=[
    go.Candlestick(
        x=stock_df.index,
        open=stock_df['Open'],
        high=stock_df['High'],
        low=stock_df['Low'],
        close=stock_df['Close']
    ),
    go.Scatter(x=stock_df.index, y=stock_df['SMA20'], line=dict(color='blue', width=1)),
    go.Scatter(x=stock_df.index, y=stock_df['SMA20_Upper_std1'], line=dict(color='green', width=0.4), fill='tonextx'),
    go.Scatter(x=stock_df.index, y=stock_df['SMA20_Upper_std2'], line=dict(color='red', width=0.4), fill='tonextx'),
    go.Scatter(x=stock_df.index, y=stock_df['SMA20_Upper_std3'], line=dict(color='purple', width=0.4), fill='tonextx'),
    go.Scatter(x=stock_df.index, y=stock_df['SMA20_Lower_std1'], line=dict(color='green', width=0.4), fill='tonextx'),
    go.Scatter(x=stock_df.index, y=stock_df['SMA20_Lower_std2'], line=dict(color='red', width=0.4)),
    go.Scatter(x=stock_df.index, y=stock_df['SMA20_Lower_std3'], line=dict(color='purple', width=0.4)),
])
fig.update_layout(xaxis_rangeslider_visible=False, height=700)
fig.show()
# Out:
# <div>                            <div id="5d2f7bf6-c8f9-4832-a869-053f3d946470" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d2f7bf6-c8f9-4832-a869-053f3d946470")) {                    Plotly.newPlot(                        "5d2f7bf6-c8f9-4832-a869-053f3d946470",                        [{"close": [1243.469970703125, 1253.030029296875, 1249.530029296875, 1249.1199951171875, 1246.780029296875, 1262.449951171875, 1251.800048828125, 1255.3800048828125, 1237.3199462890625, 1247.5, 1238.219970703125, 1217.969970703125, 1224.219970703125, 1221.1500244140625, 1214.800048828125, 1223.3199462890625, 1227.050048828125, 1229.6199951171875, 1250.1800537109375, 1274.0999755859375, 1279.300048828125, 1292.199951171875, 1297.280029296875, 1293.300048828125, 129
# ...
